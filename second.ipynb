# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('cars.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Make      Model  Variant Ex-Showroom_Price Displacement  \
# 0           0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc
# 1           1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc
# 2           2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc
# 3           3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc
# 4           4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc
#
#    Cylinders  Valves_Per_Cylinder              Drivetrain  \
# 0        2.0                  2.0  RWD (Rear Wheel Drive)
# 1        2.0                  2.0  RWD (Rear Wheel Drive)
# 2        2.0                  2.0  RWD (Rear Wheel Drive)
# 3        2.0                  2.0  RWD (Rear Wheel Drive)
# 4        2.0                  2.0  RWD (Rear Wheel Drive)
#
#   Cylinder_Configuration  ... Leather_Wrapped_Steering Automatic_Headlamps  \
# 0                In-line  ...                      NaN                 NaN
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0        Make      Model        Variant Ex-Showroom_Price  \
# 0              0        Tata  Nano Genx             Xt      Rs. 2,92,667
# 1              1        Tata  Nano Genx             Xe      Rs. 2,36,447
# 2              2        Tata  Nano Genx        Emax Xm      Rs. 2,96,661
# 3              3        Tata  Nano Genx            Xta      Rs. 3,34,768
# 4              4        Tata  Nano Genx             Xm      Rs. 2,72,223
# ...          ...         ...        ...            ...               ...
# 1271        1271       Honda       City   Vx Mt Diesel     Rs. 13,02,000
# 1272        1272       Honda       City   Zx Mt Diesel     Rs. 14,21,000
# 1273        1273       Honda       City  Zx Cvt Petrol     Rs. 14,31,000
# 1274        1274       Honda       City   V Cvt Petrol     Rs. 12,01,000
# 1275        1275  Mitsubishi    Montero         3.2 At     Rs. 68,62,560
#
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0    Cylinders  Valves_Per_Cylinder        Doors  \
# count  1276.000000  1210.000000          1174.000000  1272.000000
# mean    637.500000     4.380992             3.977853     4.550314
# std     368.493781     1.660957             0.833763     0.747816
# min       0.000000     2.000000             1.000000     2.000000
# 25%     318.750000     4.000000             4.000000     4.000000
# 50%     637.500000     4.000000             4.000000     5.000000
# 75%     956.250000     4.000000             4.000000     5.000000
# max    1275.000000    16.000000            16.000000     5.000000
#
#        Seating_Capacity  Number_of_Airbags  USB_Ports
# count       1270.000000        1141.000000  29.000000
# mean           5.270079           3.787029   1.793103
# std            1.145231           2.522399   0.773642
# min            2.000000           1.000000   1.000000
# 25%            5.000000           2.000000   1.000000
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Make', 'Model', 'Variant', 'Ex-Showroom_Price',
#        'Displacement', 'Cylinders', 'Valves_Per_Cylinder', 'Drivetrain',
#        'Cylinder_Configuration',
#        ...
#        'Leather_Wrapped_Steering', 'Automatic_Headlamps', 'Engine_Type',
#        'ASR_/_Traction_Control', 'Cruise_Control', 'USB_Ports',
#        'Heads-Up_Display', 'Welcome_Lights', 'Battery', 'Electric_Range'],
#       dtype='object', length=141)

# %%
pd.isnull(df).sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of       Unnamed: 0   Make  Model  Variant  Ex-Showroom_Price  Displacement  \
# 0          False  False  False    False              False         False
# 1          False  False  False    False              False         False
# 2          False  False  False    False              False         False
# 3          False  False  False    False              False         False
# 4          False  False  False    False              False         False
# ...          ...    ...    ...      ...                ...           ...
# 1271       False  False  False    False              False         False
# 1272       False  False  False    False              False         False
# 1273       False  False  False    False              False         False
# 1274       False  False  False    False              False         False
# 1275       False  False  False    False              False         False
#
# ...

# %%
sortwala=df.groupby(['Make'],as_index=False)['Ex-Showroom_Price'].sum().sort_values(by='Ex-Showroom_Price',ascending=False).head(10)

# %%
sortwala
# Out:
#           Make                                  Ex-Showroom_Price
# 22       Lexus  Rs. 99,00,000Rs. 1,96,00,000Rs. 2,32,90,000Rs....
# 10       Force  Rs. 9,99,000Rs. 10,75,000Rs. 12,99,000Rs. 13,3...
# 31     Porsche  Rs. 89,95,000Rs. 85,95,000Rs. 2,12,63,000Rs. 2...
# 12       Honda  Rs. 7,45,000Rs. 9,09,000Rs. 7,89,000Rs. 8,65,0...
# 9         Fiat  Rs. 6,77,618Rs. 7,39,074Rs. 9,77,516Rs. 8,10,2...
# 11        Ford  Rs. 6,76,400Rs. 7,90,900Rs. 8,36,400Rs. 5,91,4...
# 23    Mahindra  Rs. 6,57,628Rs. 6,85,729Rs. 7,50,428Rs. 27,70,...
# 14        Icml  Rs. 6,42,478Rs. 5,89,678Rs. 6,89,761Rs. 7,88,1...
# 4          Bmw  Rs. 59,30,000Rs. 58,80,000Rs. 56,00,000Rs. 73,...
# 20  Land Rover  Rs. 57,06,000Rs. 60,89,000Rs. 1,02,05,494Rs. 9...

# %%
topten=sortwala.head(10)

# %%
topten.columns
# Out:
# Index(['Make', 'Ex-Showroom_Price'], dtype='object')

# %%
ax = sns.countplot(data=topten, x='Make')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
maximake = df.groupby(['Make'],as_index=False).head(10)

# %%
maximake
# Out:
#       Unnamed: 0        Make         Model         Variant Ex-Showroom_Price  \
# 0              0        Tata     Nano Genx              Xt      Rs. 2,92,667
# 1              1        Tata     Nano Genx              Xe      Rs. 2,36,447
# 2              2        Tata     Nano Genx         Emax Xm      Rs. 2,96,661
# 3              3        Tata     Nano Genx             Xta      Rs. 3,34,768
# 4              4        Tata     Nano Genx              Xm      Rs. 2,72,223
# ...          ...         ...           ...             ...               ...
# 1261        1261  Mitsubishi  Pajero Sport  Select Plus Mt     Rs. 29,92,800
# 1262        1262  Mitsubishi  Pajero Sport  Select Plus At     Rs. 29,52,500
# 1263        1263     Bentley   Flying Spur              V8   Rs. 3,41,67,064
# 1264        1264     Bentley   Flying Spur             W12   Rs. 3,93,82,083
# 1275        1275  Mitsubishi       Montero          3.2 At     Rs. 68,62,560
#
# ...

# %%
maxi = df.groupby(['Model','Make'],as_index=False)['Ex-Showroom_Price'].sum().sort_values(by='Ex-Showroom_Price',ascending=False).head(10)

# %%
maxi
# Out:
#                   Model      Make  \
# 172             Rx 450H     Lexus
# 226                  Xj    Jaguar
# 116  Land Cruiser Prado    Toyota
# 181             Scorpio  Mahindra
# 61                Creta   Hyundai
# 187             Terrano    Nissan
# 208               Verna   Hyundai
# 129             Marazzo  Mahindra
# 98               Gurkha     Force
# 166               Rapid     Skoda
#
#                                      Ex-Showroom_Price
# 172                                      Rs. 99,00,000
# 226        Rs. 97,38,609Rs. 1,07,25,145Rs. 1,11,29,599
# 116                                      Rs. 96,30,000
# 181  Rs. 9,99,994Rs. 12,36,258Rs. 11,23,158Rs. 12,2...
# 61   Rs. 9,99,990Rs. 9,99,990Rs. 12,32,534Rs. 13,94...
# 187  Rs. 9,99,900Rs. 14,64,900Rs. 9,99,900Rs. 12,35...
# 208  Rs. 9,99,900Rs. 11,72,544Rs. 13,01,881Rs. 11,7...
# 129  Rs. 9,99,900Rs. 11,56,471Rs. 13,08,592Rs. 14,6...
# 98   Rs. 9,99,000Rs. 10,75,000Rs. 12,99,000Rs. 13,3...
# ...

# %%
maxi.count()
# Out:
# Model                10
# Make                 10
# Ex-Showroom_Price    10
# dtype: int64

# %%
maxi.describe()
# Out:
#           Model      Make Ex-Showroom_Price
# count        10        10                10
# unique       10         8                10
# top     Rx 450H  Mahindra     Rs. 99,00,000
# freq          1         2                 1

# %%
df.count()
# Out:
# Unnamed: 0           1276
# Make                 1201
# Model                1276
# Variant              1276
# Ex-Showroom_Price    1276
#                      ...
# USB_Ports              29
# Heads-Up_Display       51
# Welcome_Lights         69
# Battery                13
# Electric_Range         17
# Length: 141, dtype: int64

# %%
len(maxi.index)
# Out:
# 10

# %%
df2 = len(df[df["Make"]==""])

# %%
df2
# Out:
# 0

# %%
topcolumn=df.count(axis='columns').head(10)

# %%
topcolumn
# Out:
# 0    76
# 1    66
# 2    69
# 3    77
# 4    68
# 5    70
# 6    65
# 7    73
# 8    67
# 9    69
# dtype: int64

# %%
topcolumn.describe()
# Out:
# count    10.000000
# mean     70.000000
# std       4.082483
# min      65.000000
# 25%      67.250000
# 50%      69.000000
# 75%      72.250000
# max      77.000000
# dtype: float64

# %%
topmaker = df.pivot_table(index = ['Make'], aggfunc ='size')

# %%
topmaker
# Out:
# Make
# Aston Martin          3
# Audi                 31
# Bajaj                 2
# Bentley               6
# Bmw                  37
# Bugatti               2
# Datsun               15
# Dc                    1
# Ferrari               8
# Fiat                 23
# Force                 6
# Ford                 43
# Honda                64
# Hyundai             130
# Icml                 11
# Isuzu                 5
# Jaguar               22
# Jeep                 28
# Kia                  21
# Lamborghini          13
# Land Rover           10
# Land Rover Rover     27
# Lexus                10
# Mahindra            119
# Maruti Suzuki       149
# Maruti Suzuki R      14
# Maserati              9
# Mg                   13
# Mini                 10
# Mitsubishi            7
# Nissan               29
# Porsche              14
# Premier               6
# Renault              36
# Skoda                43
# Tata                100
# Toyota               82
# Volkswagen           34
# ...

# %%
topcars=df.value_counts(['Make']).head(10)
topcars
# Out:
# Make
# Maruti Suzuki    149
# Hyundai          130
# Mahindra         119
# Tata             100
# Toyota            82
# Honda             64
# Skoda             43
# Ford              43
# Bmw               37
# Renault           36
# dtype: int64

# %%
topcars.plot.bar()
# Out:
# <Axes: xlabel='Make'>

# %%
topcars.plot(x='Make', kind='bar', stacked=True,
        title='Stacked Bar Graph of topcar seller')
for index, value in enumerate(topmodel):
    plt.text(value, index,
             str(value))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 3
#       1 topcars.plot(x='Make', kind='bar', stacked=True,
#       2         title='Stacked Bar Graph of topcar seller')
# ----> 3 for index, value in enumerate(topmodel):
#       4     plt.text(value, index,
#       5              str(value))
#       6 plt.show()
#
# NameError: name 'topmodel' is not defined

# %%
topmodel=df.value_counts(['Make','Model']).head(10)
topmodel

# %%
topmodel.plot(x='Make', kind='barh', stacked=True,
        title='Stacked Bar Graph of top models')
for index, value in enumerate(topmodel):
    plt.text(value, index,
             str(value))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 topmodel.plot(x='Make', kind='barh', stacked=True,
#       2         title='Stacked Bar Graph of top models')
#       3 for index, value in enumerate(topmodel):
#       4     plt.text(value, index,
#       5              str(value))
#
# NameError: name 'topmodel' is not defined

# %%
topv=df.value_counts(['Make','Model','Variant']).head(20)
topv
# Out:
# Make          Model        Variant
# Mahindra      Xuv500       W9 At                2
#                            W9                   2
#                            W7 At                2
#                            W7                   2
#                            W11 At               2
#                            W11 (O) At           2
#                            W11 (O)              2
#                            W11                  2
#                            G At                 2
# Mg            Hector       1.5L Sharp Dct       1
#                            1.5L Smart Hybrid    1
#                            1.5L Smart Dct       1
#                            1.5L Sharp Hybrid    1
# Aston Martin  Db 11        V12                  1
# Mg            Hector       1.5L Style           1
# Maserati      Levante      Gransport            1
#                            Granlusson           1
#                            Diesel               1
# ...

# %%
topv
# Out:
# Make          Model        Variant
# Mahindra      Xuv500       W9 At                2
#                            W9                   2
#                            W7 At                2
#                            W7                   2
#                            W11 At               2
#                            W11 (O) At           2
#                            W11 (O)              2
#                            W11                  2
#                            G At                 2
# Mg            Hector       1.5L Sharp Dct       1
#                            1.5L Smart Hybrid    1
#                            1.5L Smart Dct       1
#                            1.5L Sharp Hybrid    1
# Aston Martin  Db 11        V12                  1
# Mg            Hector       1.5L Style           1
# Maserati      Levante      Gransport            1
#                            Granlusson           1
#                            Diesel               1
# ...

# %%
distinct = pd.DataFrame(topcars, columns=['top10'])
distinct

distinct.to_csv('file1.csv')

# %%
df.head()

# %%
df.head()
# Out:
#    Unnamed: 0  Make      Model  Variant Ex-Showroom_Price Displacement  \
# 0           0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc
# 1           1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc
# 2           2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc
# 3           3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc
# 4           4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc
#
#    Cylinders  Valves_Per_Cylinder              Drivetrain  \
# 0        2.0                  2.0  RWD (Rear Wheel Drive)
# 1        2.0                  2.0  RWD (Rear Wheel Drive)
# 2        2.0                  2.0  RWD (Rear Wheel Drive)
# 3        2.0                  2.0  RWD (Rear Wheel Drive)
# 4        2.0                  2.0  RWD (Rear Wheel Drive)
#
#   Cylinder_Configuration  ... Leather_Wrapped_Steering Automatic_Headlamps  \
# 0                In-line  ...                      NaN                 NaN
# ...

# %%
df.drop(['Emission_Norm',
 'Engine_Location',
 'Fuel_System',
 'Fuel_Tank_Capacity',
 'Fuel_Type',
 'Height',
 'Length',
 'Width',
 'Body_Type',
 'Doors',
 'City_Mileage',
 'Highway_Mileage',
 'ARAI_Certified_Mileage',
 'ARAI_Certified_Mileage_for_CNG',
 'Kerb_Weight',
 'Gears',
 'Ground_Clearance',
 'Front_Brakes',
 'Rear_Brakes',
 'Front_Suspension',
 'Rear_Suspension',
 'Front_Track',
 'Rear_Track',
 'Front_Tyre_&_Rim',
 'Rear_Tyre_&_Rim',
 'Power_Steering',
 'Power_Windows',
 'Power_Seats',
 'Keyless_Entry',
 'Power',
 'Torque',
 'Odometer',
 'Speedometer',
 'Tachometer',
 'Tripmeter',
 'Seating_Capacity',
 'Seats_Material',
 'Type',
 'Wheelbase',
 'Wheels_Size',
 'Start_/_Stop_Button',
 '12v_Power_Outlet',
 'Audiosystem',
 'Aux-in_Compatibility',
 'Average_Fuel_Consumption',
 'Basic_Warranty',
 'Bluetooth',
 'Boot-lid_Opener',
 'Boot_Space',
 'CD_/_MP3_/_DVD_Player',
 'Central_Locking',
 'Child_Safety_Locks',
 'Clock',
 'Cup_Holders',
 'Distance_to_Empty',
 'Door_Pockets',
 'Engine_Malfunction_Light',
 'Extended_Warranty',
 'FM_Radio',
 'Fuel-lid_Opener',
 'Fuel_Gauge',
 'Handbrake',
 'Instrument_Console',
 'Low_Fuel_Warning',
 'Minimum_Turning_Radius',
 'Multifunction_Display',
 'Sun_Visor',
 'Third_Row_AC_Vents',
 'Ventilation_System',
 'Auto-Dimming_Rear-View_Mirror',
 'Hill_Assist',
 'Gear_Indicator',
 '3_Point_Seat-Belt_in_Middle_Rear_Seat',
 'Ambient_Lightning',
 'Cargo/Boot_Lights',
 'Drive_Modes',
 'Engine_Immobilizer',
 'High_Speed_Alert_System',
 'Lane_Watch_Camera/_Side_Mirror_Camera',
 'Passenger_Side_Seat-Belt_Reminder',
 'Seat_Back_Pockets',
 'Voice_Recognition',
 'Walk_Away_Auto_Car_Lock',
 'ABS_(Anti-lock_Braking_System)',
 'Headlight_Reminder',
 'Adjustable_Headrests',
 'Gross_Vehicle_Weight',
 'Airbags',
 'Door_Ajar_Warning',
 'EBD_(Electronic_Brake-force_Distribution)',
 'Fasten_Seat_Belt_Warning',
 'Gear_Shift_Reminder',
 'Number_of_Airbags',
 'Compression_Ratio',
 'Adjustable_Steering_Column',
 'Other_Specs',
 'Other_specs',
 'Parking_Assistance',
 'Key_Off_Reminder',
 'USB_Compatibility',
 'Android_Auto',
 'Apple_CarPlay',
 'Cigarette_Lighter',
 'Infotainment_Screen',
 'Multifunction_Steering_Wheel',
 'Average_Speed',
 'EBA_(Electronic_Brake_Assist)',
 'Seat_Height_Adjustment',
 'Navigation_System',
 'Second_Row_AC_Vents',
 'Tyre_Pressure_Monitoring_System',
 'Rear_Center_Armrest',
 'iPod_Compatibility',
 'ESP_(Electronic_Stability_Program)',
 'Cooled_Glove_Box',
 'Recommended_Tyre_Pressure',
 'Heated_Seats',
 'Turbocharger',
 'ISOFIX_(Child-Seat_Mount)',
 'Rain_Sensing_Wipers',
 'Paddle_Shifters'], axis = 1, inplace = True)

# %%
df.head(20)
df.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0        Make      Model        Variant Ex-Showroom_Price  \
# 0              0        Tata  Nano Genx             Xt      Rs. 2,92,667
# 1              1        Tata  Nano Genx             Xe      Rs. 2,36,447
# 2              2        Tata  Nano Genx        Emax Xm      Rs. 2,96,661
# 3              3        Tata  Nano Genx            Xta      Rs. 3,34,768
# 4              4        Tata  Nano Genx             Xm      Rs. 2,72,223
# ...          ...         ...        ...            ...               ...
# 1271        1271       Honda       City   Vx Mt Diesel     Rs. 13,02,000
# 1272        1272       Honda       City   Zx Mt Diesel     Rs. 14,21,000
# 1273        1273       Honda       City  Zx Cvt Petrol     Rs. 14,31,000
# 1274        1274       Honda       City   V Cvt Petrol     Rs. 12,01,000
# 1275        1275  Mitsubishi    Montero         3.2 At     Rs. 68,62,560
#
# ...

# %%
my_list = list(df)

# %%
df.describe()
# Out:
#         Unnamed: 0    Cylinders  Valves_Per_Cylinder  USB_Ports
# count  1276.000000  1210.000000          1174.000000  29.000000
# mean    637.500000     4.380992             3.977853   1.793103
# std     368.493781     1.660957             0.833763   0.773642
# min       0.000000     2.000000             1.000000   1.000000
# 25%     318.750000     4.000000             4.000000   1.000000
# 50%     637.500000     4.000000             4.000000   2.000000
# 75%     956.250000     4.000000             4.000000   2.000000
# max    1275.000000    16.000000            16.000000   3.000000

# %%
df.head()
# Out:
#    Unnamed: 0  Make      Model  Variant Ex-Showroom_Price Displacement  \
# 0           0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc
# 1           1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc
# 2           2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc
# 3           3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc
# 4           4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc
#
#    Cylinders  Valves_Per_Cylinder              Drivetrain  \
# 0        2.0                  2.0  RWD (Rear Wheel Drive)
# 1        2.0                  2.0  RWD (Rear Wheel Drive)
# 2        2.0                  2.0  RWD (Rear Wheel Drive)
# 3        2.0                  2.0  RWD (Rear Wheel Drive)
# 4        2.0                  2.0  RWD (Rear Wheel Drive)
#
#   Cylinder_Configuration Leather_Wrapped_Steering Automatic_Headlamps  \
# 0                In-line                      NaN                 NaN
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Make', 'Model', 'Variant', 'Ex-Showroom_Price',
#        'Displacement', 'Cylinders', 'Valves_Per_Cylinder', 'Drivetrain',
#        'Cylinder_Configuration', 'Leather_Wrapped_Steering',
#        'Automatic_Headlamps', 'Engine_Type', 'ASR_/_Traction_Control',
#        'Cruise_Control', 'USB_Ports', 'Heads-Up_Display', 'Welcome_Lights',
#        'Battery', 'Electric_Range'],
#       dtype='object')

# %%
df.drop(['Cylinders', 'Valves_Per_Cylinder', 'Drivetrain',
       'Cylinder_Configuration', 'Leather_Wrapped_Steering',
       'Automatic_Headlamps', 'Engine_Type', 'ASR_/_Traction_Control',
       'Cruise_Control', 'USB_Ports', 'Heads-Up_Display', 'Welcome_Lights',
       'Battery', 'Electric_Range'], axis = 1, inplace = True)

# %%
df.head(20)
# Out:
#     Unnamed: 0     Make      Model          Variant Ex-Showroom_Price  \
# 0            0     Tata  Nano Genx               Xt      Rs. 2,92,667
# 1            1     Tata  Nano Genx               Xe      Rs. 2,36,447
# 2            2     Tata  Nano Genx          Emax Xm      Rs. 2,96,661
# 3            3     Tata  Nano Genx              Xta      Rs. 3,34,768
# 4            4     Tata  Nano Genx               Xm      Rs. 2,72,223
# 5            5     Tata  Nano Genx              Xma      Rs. 3,14,815
# 6            6   Datsun    Redi-Go                D      Rs. 2,79,650
# 7            7   Datsun    Redi-Go                T      Rs. 3,51,832
# 8            8   Datsun    Redi-Go                A      Rs. 3,33,419
# 9            9   Datsun    Redi-Go                S      Rs. 3,62,000
# 10          10   Datsun    Redi-Go            1.0 S      Rs. 3,90,000
# 11          11   Datsun    Redi-Go        1.0 S Amt      Rs. 4,37,065
# ...

# %%
topcars.plot.bar()
topv.plot.bar()
# Out:
# <Axes: xlabel='Make,Model,Variant'>

# %%
topv.plot.bar()
# Out:
# <Axes: xlabel='Make,Model,Variant'>

# %% [markdown]
# # conclusion
#
# from the above data it is concluded that maximum cars is manufactured by Maruti suzuki but Tata has more varient of car while on the otherhand Tata Nexon is most loved car by customer
